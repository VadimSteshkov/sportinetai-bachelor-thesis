# %%
import pandas as pd
import numpy as np

# Load data
ufc_data_cleaned = pd.read_csv('../data/processed/ufc_data_final.csv')

# 1. Check for missing values
print("=== Basic Missing Values Check ===")
print(ufc_data_cleaned.isnull().sum())  # Number of missing values in each column
print(f"Total missing values: {ufc_data_cleaned.isnull().sum().sum()}")  # Total number of missing values

# 2. Check for duplicate rows
print("\n=== Duplicate Rows Check ===")
print(f"Total duplicate rows: {ufc_data_cleaned.duplicated().sum()}")

# 3. Check for empty or whitespace-only strings
print("\n=== Empty or Whitespace Strings Check ===")
for col in ufc_data_cleaned.select_dtypes(include=['object']).columns:
    empty_or_whitespace = ufc_data_cleaned[col].str.isspace().sum()
    print(f"{col}: {empty_or_whitespace} empty or whitespace strings")

# 4. Check for zero values
print("\n=== Zero Values Check ===")
zero_counts = (ufc_data_cleaned == 0).sum()
print(zero_counts[zero_counts > 0])  # Show only columns with zeros

# 5. Check for outliers
print("\n=== Outliers Check ===")
for col in ufc_data_cleaned.select_dtypes(include=[np.number]).columns:
    q1 = ufc_data_cleaned[col].quantile(0.25)
    q3 = ufc_data_cleaned[col].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers = ufc_data_cleaned[(ufc_data_cleaned[col] < lower_bound) | (ufc_data_cleaned[col] > upper_bound)]
    print(f"{col}: {len(outliers)} outliers")

# 6. Check data types
print("\n=== Data Types ===")
print(ufc_data_cleaned.dtypes)

# 7. Check unique values in each column
print("\n=== Unique Values Check ===")
for col in ufc_data_cleaned.columns:
    unique_values = ufc_data_cleaned[col].nunique()
    print(f"{col}: {unique_values} unique values")

# 8. Descriptive statistics
print("\n=== Descriptive Statistics ===")
print(ufc_data_cleaned.describe(include='all'))  # General info for numeric and categorical data

# 9. Check for negative values (if not expected)
print("\n=== Negative Values Check ===")
negative_counts = (ufc_data_cleaned.select_dtypes(include=[np.number]) < 0).sum()
print(negative_counts[negative_counts > 0])  # Show only columns with negative values

# 10. Check if data type matches content (e.g., numeric strings)
print("\n=== Data Consistency Check (Numeric Columns) ===")
for col in ufc_data_cleaned.select_dtypes(include=['object']).columns:
    try:
        # Try converting to numbers
        ufc_data_cleaned[col].astype(float)
        print(f"{col}: Can be converted to numeric")
    except ValueError:
        print(f"{col}: Cannot be converted to numeric")

# Summary
print("\n=== Final Check Summary ===")
print("1. Missing values handled? Check above.")
print("2. Duplicates resolved? Check above.")
print("3. Data distribution looks reasonable? Check outliers section.")
# Out:
# === Basic Missing Values Check ===
# event_name            0
# date                  0
# location              0
# r_fighter             0
# b_fighter             0
#                      ..
# td_acc_total_diff     0
# str_def_total_diff    0
# td_def_total_diff     0
# sub_avg_diff          0
# td_avg_diff           0
# Length: 97, dtype: int64
# Total missing values: 0
#
# === Duplicate Rows Check ===
# Total duplicate rows: 0
#
# === Empty or Whitespace Strings Check ===
# event_name: 0 empty or whitespace strings
# date: 0 empty or whitespace strings
# location: 0 empty or whitespace strings
# r_fighter: 0 empty or whitespace strings
# b_fighter: 0 empty or whitespace strings
# winner: 0 empty or whitespace strings
# weight_class: 0 empty or whitespace strings
# gender: 0 empty or whitespace strings
# method: 0 empty or whitespace strings
# referee: 0 empty or whitespace strings
# r_stance: 0 empty or whitespace strings
# b_stance: 0 empty or whitespace strings
#
# === Zero Values Check ===
# is_title_bout         7024
# r_kd                  5858
# r_sig_str              117
# r_sig_str_att           37
# r_sig_str_acc          117
#                       ...
# td_acc_total_diff      342
# str_def_total_diff     434
# td_def_total_diff      258
# sub_avg_diff           886
# td_avg_diff            202
# Length: 74, dtype: int64
#
# === Outliers Check ===
# is_title_bout: 415 outliers
# finish_round: 0 outliers
# total_rounds: 828 outliers
# time_sec: 29 outliers
# r_kd: 1581 outliers
# r_sig_str: 244 outliers
# r_sig_str_att: 217 outliers
# r_sig_str_acc: 266 outliers
# r_str: 166 outliers
# r_str_att: 100 outliers
# r_str_acc: 77 outliers
# r_td: 276 outliers
# r_td_att: 410 outliers
# r_td_acc: 0 outliers
# r_sub_att: 279 outliers
# r_rev: 815 outliers
# r_ctrl_sec: 379 outliers
# r_wins_total: 129 outliers
# r_losses_total: 123 outliers
# r_age: 129 outliers
# r_height: 22 outliers
# r_weight: 445 outliers
# r_reach: 132 outliers
# r_SLpM_total: 248 outliers
# r_SApM_total: 281 outliers
# r_sig_str_acc_total: 218 outliers
# r_td_acc_total: 141 outliers
# r_str_def_total: 273 outliers
# r_td_def_total: 281 outliers
# r_sub_avg: 278 outliers
# r_td_avg: 175 outliers
# b_kd: 1164 outliers
# b_sig_str: 241 outliers
# b_sig_str_att: 174 outliers
# b_sig_str_acc: 349 outliers
# b_str: 146 outliers
# b_str_att: 96 outliers
# b_str_acc: 152 outliers
# b_td: 881 outliers
# b_td_att: 362 outliers
# b_td_acc: 0 outliers
# b_sub_att: 1543 outliers
# b_rev: 815 outliers
# b_ctrl_sec: 516 outliers
# b_wins_total: 161 outliers
# b_losses_total: 104 outliers
# b_age: 120 outliers
# b_height: 23 outliers
# b_weight: 442 outliers
# b_reach: 107 outliers
# b_SLpM_total: 109 outliers
# b_SApM_total: 414 outliers
# b_sig_str_acc_total: 415 outliers
# b_td_acc_total: 225 outliers
# b_str_def_total: 325 outliers
# b_td_def_total: 560 outliers
# b_sub_avg: 334 outliers
# b_td_avg: 190 outliers
# kd_diff: 2560 outliers
# sig_str_diff: 445 outliers
# sig_str_att_diff: 529 outliers
# sig_str_acc_diff: 322 outliers
# str_diff: 611 outliers
# str_att_diff: 555 outliers
# str_acc_diff: 276 outliers
# td_diff: 637 outliers
# td_att_diff: 637 outliers
# td_acc_diff: 0 outliers
# sub_att_diff: 3001 outliers
# rev_diff: 1158 outliers
# ctrl_sec_diff: 925 outliers
# wins_total_diff: 184 outliers
# losses_total_diff: 166 outliers
# age_diff: 52 outliers
# height_diff: 43 outliers
# weight_diff: 2778 outliers
# reach_diff: 149 outliers
# SLpM_total_diff: 124 outliers
# SApM_total_diff: 231 outliers
# sig_str_acc_total_diff: 236 outliers
# td_acc_total_diff: 248 outliers
# str_def_total_diff: 302 outliers
# td_def_total_diff: 191 outliers
# sub_avg_diff: 479 outliers
# td_avg_diff: 252 outliers
#
# === Data Types ===
# event_name             object
# date                   object
# location               object
# r_fighter              object
# b_fighter              object
#                        ...
# td_acc_total_diff     float64
# str_def_total_diff    float64
# td_def_total_diff     float64
# sub_avg_diff          float64
# td_avg_diff           float64
# Length: 97, dtype: object
#
# === Unique Values Check ===
# event_name: 683 unique values
# date: 677 unique values
# location: 168 unique values
# r_fighter: 1796 unique values
# b_fighter: 2301 unique values
# winner: 2 unique values
# weight_class: 109 unique values
# is_title_bout: 2 unique values
# gender: 2 unique values
# method: 7 unique values
# finish_round: 5 unique values
# total_rounds: 4 unique values
# time_sec: 339 unique values
# referee: 220 unique values
# r_kd: 6 unique values
# r_sig_str: 190 unique values
# r_sig_str_att: 358 unique values
# r_sig_str_acc: 96 unique values
# r_str: 250 unique values
# r_str_att: 391 unique values
# r_str_acc: 95 unique values
# r_td: 17 unique values
# r_td_att: 28 unique values
# r_td_acc: 71 unique values
# r_sub_att: 11 unique values
# r_rev: 7 unique values
# r_ctrl_sec: 776 unique values
# r_wins_total: 51 unique values
# r_losses_total: 31 unique values
# r_age: 44 unique values
# r_height: 23 unique values
# r_weight: 63 unique values
# r_reach: 27 unique values
# r_stance: 5 unique values
# r_SLpM_total: 558 unique values
# r_SApM_total: 535 unique values
# r_sig_str_acc_total: 65 unique values
# r_td_acc_total: 80 unique values
# r_str_def_total: 61 unique values
# r_td_def_total: 89 unique values
# r_sub_avg: 53 unique values
# r_td_avg: 442 unique values
# b_kd: 5 unique values
# b_sig_str: 178 unique values
# b_sig_str_att: 350 unique values
# b_sig_str_acc: 91 unique values
# b_str: 226 unique values
# b_str_att: 374 unique values
# b_str_acc: 97 unique values
# b_td: 13 unique values
# b_td_att: 32 unique values
# b_td_acc: 70 unique values
# b_sub_att: 8 unique values
# b_rev: 5 unique values
# b_ctrl_sec: 649 unique values
# b_wins_total: 53 unique values
# b_losses_total: 31 unique values
# b_age: 45 unique values
# b_height: 23 unique values
# b_weight: 76 unique values
# b_reach: 27 unique values
# b_stance: 5 unique values
# b_SLpM_total: 606 unique values
# b_SApM_total: 614 unique values
# b_sig_str_acc_total: 74 unique values
# b_td_acc_total: 81 unique values
# b_str_def_total: 73 unique values
# b_td_def_total: 90 unique values
# b_sub_avg: 61 unique values
# b_td_avg: 470 unique values
# kd_diff: 10 unique values
# sig_str_diff: 219 unique values
# sig_str_att_diff: 332 unique values
# sig_str_acc_diff: 299 unique values
# str_diff: 350 unique values
# str_att_diff: 428 unique values
# str_acc_diff: 303 unique values
# td_diff: 28 unique values
# td_att_diff: 55 unique values
# td_acc_diff: 239 unique values
# sub_att_diff: 18 unique values
# rev_diff: 9 unique values
# ctrl_sec_diff: 1302 unique values
# wins_total_diff: 122 unique values
# losses_total_diff: 55 unique values
# age_diff: 36 unique values
# height_diff: 41 unique values
# weight_diff: 234 unique values
# reach_diff: 44 unique values
# SLpM_total_diff: 1855 unique values
# SApM_total_diff: 1818 unique values
# sig_str_acc_total_diff: 185 unique values
# td_acc_total_diff: 291 unique values
# str_def_total_diff: 187 unique values
# td_def_total_diff: 313 unique values
# sub_avg_diff: 197 unique values
# td_avg_diff: 1740 unique values
#
# === Descriptive Statistics ===
#                event_name        date                location   r_fighter  \
# count                7439        7439                    7439        7439
# unique                683         677                     168        1796
# top     ufc 2: no way out  11/19/2016  Las Vegas, Nevada, USA  Jim Miller
# freq                   15          36                    2458          33
# mean                  NaN         NaN                     NaN         NaN
# std                   NaN         NaN                     NaN         NaN
# min                   NaN         NaN                     NaN         NaN
# 25%                   NaN         NaN                     NaN         NaN
# 50%                   NaN         NaN                     NaN         NaN
# 75%                   NaN         NaN                     NaN         NaN
# max                   NaN         NaN                     NaN         NaN
#
#               b_fighter winner weight_class  is_title_bout gender  \
# count              7439   7439         7439    7439.000000   7439
# unique             2301      2          109            NaN      2
# top     Jeremy Stephens    Red  Lightweight            NaN    Men
# freq                 20   4876         1235            NaN   6706
# mean                NaN    NaN          NaN       0.055787    NaN
# std                 NaN    NaN          NaN       0.229525    NaN
# min                 NaN    NaN          NaN       0.000000    NaN
# 25%                 NaN    NaN          NaN       0.000000    NaN
# 50%                 NaN    NaN          NaN       0.000000    NaN
# 75%                 NaN    NaN          NaN       0.000000    NaN
# max                 NaN    NaN          NaN       1.000000    NaN
#
#                       method  ...  weight_diff   reach_diff  SLpM_total_diff  \
# count                   7439  ...  7439.000000  7439.000000      7439.000000
# unique                     7  ...          NaN          NaN              NaN
# top     Decision - Unanimous  ...          NaN          NaN              NaN
# freq                    2660  ...          NaN          NaN              NaN
# mean                     NaN  ...     0.171000     0.163552         0.142594
# std                      NaN  ...     6.774199     7.655441         1.585610
# min                      NaN  ...  -258.550000   -27.940000        -8.990000
# 25%                      NaN  ...     0.000000    -5.080000        -0.860000
# 50%                      NaN  ...     0.000000     0.000000         0.130000
# 75%                      NaN  ...     0.000000     5.080000         1.160000
# max                      NaN  ...    52.160000    33.020000        18.780000
#
#        SApM_total_diff  sig_str_acc_total_diff  td_acc_total_diff  \
# count      7439.000000             7439.000000        7439.000000
# unique             NaN                     NaN                NaN
# top                NaN                     NaN                NaN
# freq               NaN                     NaN                NaN
# mean         -0.171643                0.012109           0.028164
# std           1.691358                0.119919           0.276307
# min         -39.490000               -0.700000          -1.000000
# 25%          -1.040000               -0.060000          -0.130000
# 50%          -0.120000                0.010000           0.020000
# 75%           0.790000                0.080000           0.190000
# max          12.640000                0.830000           1.000000
#
#         str_def_total_diff  td_def_total_diff  sub_avg_diff  td_avg_diff
# count          7439.000000        7439.000000   7439.000000  7439.000000
# unique                 NaN                NaN           NaN          NaN
# top                    NaN                NaN           NaN          NaN
# freq                   NaN                NaN           NaN          NaN
# mean              0.020909           0.037513      0.045651     0.134487
# std               0.113455           0.292107      1.052065     1.781598
# min              -0.580000          -1.000000    -15.100000   -11.770000
# 25%              -0.040000          -0.140000     -0.400000    -0.870000
# 50%               0.010000           0.020000      0.000000     0.090000
# 75%               0.080000           0.210000      0.500000     1.160000
# max               0.720000           1.000000     13.800000    11.110000
#
# [11 rows x 97 columns]
#
# === Negative Values Check ===
# kd_diff                   1071
# sig_str_diff              2865
# sig_str_att_diff          3092
# sig_str_acc_diff          2985
# str_diff                  2960
# str_att_diff              3099
# str_acc_diff              3112
# td_diff                   2070
# td_att_diff               2813
# td_acc_diff               2231
# sub_att_diff              1201
# rev_diff                   580
# ctrl_sec_diff             2997
# wins_total_diff           2843
# losses_total_diff         3142
# age_diff                  3152
# height_diff               3089
# weight_diff               1299
# reach_diff                2752
# SLpM_total_diff           3321
# SApM_total_diff           3957
# sig_str_acc_total_diff    3332
# td_acc_total_diff         3236
# str_def_total_diff        3006
# td_def_total_diff         3284
# sub_avg_diff              3023
# td_avg_diff               3356
# dtype: int64
#
# === Data Consistency Check (Numeric Columns) ===
# event_name: Cannot be converted to numeric
# date: Cannot be converted to numeric
# location: Cannot be converted to numeric
# r_fighter: Cannot be converted to numeric
# b_fighter: Cannot be converted to numeric
# winner: Cannot be converted to numeric
# weight_class: Cannot be converted to numeric
# gender: Cannot be converted to numeric
# method: Cannot be converted to numeric
# referee: Cannot be converted to numeric
# r_stance: Cannot be converted to numeric
# b_stance: Cannot be converted to numeric
#
# === Final Check Summary ===
# 1. Missing values handled? Check above.
# 2. Duplicates resolved? Check above.
# 3. Data distribution looks reasonable? Check outliers section.

# %%
import numpy as np

# Select numeric columns
numeric_columns = ufc_data_cleaned.select_dtypes(include=[np.number])

# Create a DataFrame to store outliers with column and value info
outliers = pd.DataFrame(columns=["Column", "Value", "Index"])

for col in numeric_columns.columns:
    Q1 = numeric_columns[col].quantile(0.25)  # First quartile
    Q3 = numeric_columns[col].quantile(0.75)  # Third quartile
    IQR = Q3 - Q1  # Interquartile range

    # Outlier boundaries
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Select outliers
    outliers_in_col = ufc_data_cleaned[(numeric_columns[col] < lower_bound) | (numeric_columns[col] > upper_bound)]

    # Add outliers to the overall DataFrame
    for idx, value in outliers_in_col[col].items():
        outliers = pd.concat([outliers, pd.DataFrame({
            "Column": [col],
            "Value": [value],
            "Index": [idx]
        })])

# Remove duplicates (one row can be an outlier in several columns)
outliers = outliers.drop_duplicates(subset=["Index", "Column"])

# Show 5 examples of outliers
print(outliers.head(10))
# Out:
#           Column Value Index
# 0  is_title_bout     1    25
# 0  is_title_bout     1    62
# 0  is_title_bout     1    99
# 0  is_title_bout     1   100
# 0  is_title_bout     1   122
# 0  is_title_bout     1   123
# 0  is_title_bout     1   170
# 0  is_title_bout     1   171
# 0  is_title_bout     1   191
# 0  is_title_bout     1   242
